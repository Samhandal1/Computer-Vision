# %% [markdown]
# # Final Project
#
# Dania Pennimpede (260986441) and Samantha Handal (260983914)

# %% [markdown]
# ## Goal
#
#
# Write a python program that will analyze the two dashcam videos provided (mcgill_drive.mp4 and st-catherines_drive.mp4, each are 30 frames per second, and are taken with the same car/dashcam) and provide the following analytics:
#
# * Number of parked cars passed
# * Number of moving cars passed
# * Number of pedestrians passed

# %% [markdown]
# ## Our Approach
#
# Our approach to analyzing the two dashcam videos involved a multi-step process aimed at extracting valuable insights captured in the footage. The key steps of our approach are outlined below:
#
#
# **Step 1 - Object Detection and Tracking:**
# * We used the YOLOv8 object detection model to detect the various cars and pedestrians in each frame of the videos.
# *   The detected objects are then tracked across frames using the Deep SORT algorithm.
# *   This enables us to accurately track the movement of each detected object throughout the video and not have the objects be counted multiple times.
#
# **Step 2 - Speed Estimation:**
# *   For each tracked object, we estimate its speed by analyzing its trajectory over time.
# *   This is achieved by calculating the distance traveled by the object between consecutive frames and dividing it by the time elapsed between those frames.
# * This provides us with a measure of the speed of each object as it moves through the scene.
#
# **Step 3 - Classification:**
# * Based on the estimated speeds of the tracked objects, we classify them into two categories: moving cars and pedestrians. Moving cars are identified based on their relatively high speeds, while pedestrians are identified based on their slower speeds.
# * To identify parked cars, we analyze the movements of detected cars in the video. Parked cars are characterized by their stationary positions over an extended period. We identify instances where cars remain stationary for a significant duration, indicating that they are likely parked.

# %% [markdown]
# ## Assumptions Made
#
# * We assumed that the dashcam videos provided were captured under typical driving conditions with sufficient lighting and visibility.
# * We assumed that the objects of interest (cars, pedestrians, etc.) would be adequately captured and distinguishable within the video frames.
# * We assumed a constant frame rate of 30 frames per second for both input videos.
# * We assumed no cars were reversing
# * We assumed no major obstructions prevented accurate object detecting and tracking.

# %% [markdown]
# ## Software Packages Used
# 1.   **Ultralytics YOLO:**
# * As seen in previous assignments, YOLO is a real-time object detection system that processes images or video frames and detects objects within them.
# * Our program utilizes YOLOv8 to detect cars and pedestrians in each frame of the dashcam videos.
# * YOLOv8 speed estimation algorithm was used as inspiration for segregating between parked and moving cars: https://github.com/ultralytics/ultralytics/blob/main/ultralytics/solutions/speed_estimation.py
#
# 2.   **Deep SORT:**
# * As seen in class, Deep SORT is an extension of the SORT algorithm that integrates appearance information into the tracking process.
# * Our program utilizes Deep SORT to track the objects detected by YOLO across video frames.
# * DeepSORT source code was adjusted to work with more recent versions of colab: https://github.com/nwojke/deep_sort/tree/master, dependencies imported above

# %% [markdown]
# ## Results
#
# **Manual Approximation**
#
# *McGill:*
#
# *   Number of Pedestrians: ~30
# * Number of Moving Cars: ~25
# * Number of Parked Cars: ~15
#
# *Saint Catherine:*
#
# *   Number of Pedestrians: ~90
# * Number of Moving Cars: ~8
# * Number of Parked Cars: ~60
#
# **Detected By Program**
#
# *McGill:*
#
# *   Number of Pedestrians: 25
# * Number of Moving Cars: 37
# * Number of Parked Cars: 15
#
# *Saint Catherine:*
#
# *   Number of Pedestrians: 64
# * Number of Moving Cars: 57
# * Number of Parked Cars: 12

# %% [markdown]
# ## Program Performance and Problems
#
# **Performance**
#
# Overall, the program performed reasonably well when it came to detecting moving cars, parked cars and pedestrians in the McGill video:
#
# *   25 out of 30 pedestrians were detected -> 0 false positives, 5 missing pedestrians
# *   37 out of 25 moving cars were detected -> 12 false positives, 0 missing moving cars
# * 15 out of 15 parked cars were detected -> 0 false positives, 0 missing parked cars
#
# In terms of the Saint Catherine video, our program performed well in terms of detecting pedestrians and cars, but struggled to differentiate between moving and parked cars:
#
# * 64 out of 90 pedestrians were detected -> 0 false positives, 26 missing pedestrians
# * 57 out of 8 moving cars were detected -> 49 false positives, 0 missing moving cars
# * 12 out of 60 parked cars were detected -> 0 false positves, 48 missing parked cars
#
#
#
# **Problems**
#
# *Speed Estimation*
#
# * The speed estimation technique used in our program relied solely on analyzing object trajectories, which might not accurately capture complex movements such as acceleration or deceleration. This lead to inaccuracies in speed measurements.
#
# *Car Classification*
#
# * Our program encountered challenges in differentiating between moving and parked cars, particularly in crowded or complex scenes. This led to a high number of false positives in the classification of moving cars, as well as a significant number of missing parked cars.
#
#
# **Possible Improvements**
#
# *   Improve our speed estimation method by implementing scaling techniques that could enhance the accuracy of speed measurements by considering factors like object acceleration and deceleration.
# *   By analyzing the movements of detected cars in relation to static objects, our program could improve the classification of parked cars.
# * Prepare for edge cases such as the car performing turns, switching lanes, or the lighting effects of the video.

# %% [markdown]
# ## Code Developed

# %%
# Install the necessary dependencies
# !pip install ultralytics==8.0.33 tensorflow==2.11.0 scikit-image==0.19.3 filterpy==1.4.5

# %%
# !pip install scikit-learn==0.22.2.post1

# %%
# Ultralytics YOLO 🚀, AGPL-3.0 license

from collections import defaultdict
from time import time

import cv2
import numpy as np

class SpeedEstimator:
    """A class to estimation speed of objects in real-time video stream based on their tracks."""

    def __init__(self):
        """Initializes the speed-estimator class with default values for Visual, Image, track and speed parameters."""

        # Region information
        self.reg_pts = [(20, 400), (1260, 400)]

        # Predict/track information
        self.boxes = None
        self.trk_ids = None
        self.trk_pts = None
        self.trk_history = defaultdict(list)

        # Speed estimator information
        self.current_time = 0
        self.dist_data = {}
        self.trk_idslist = []
        self.spdl_dist_thresh = 10
        self.trk_previous_times = {}
        self.trk_previous_points = {}

    def set_args(
        self,
        reg_pts,
        spdl_dist_thresh=10
    ):
        """
        Configures the speed estimation and display parameters.

        Args:
            reg_pts (list): Initial list of points defining the speed calculation region.
            spdl_dist_thresh (int): Euclidean distance threshold for speed line
        """
        if reg_pts is None:
            print("Region points not provided, using default values")
        else:
            self.reg_pts = reg_pts
        self.spdl_dist_thresh = spdl_dist_thresh

    def store_track_info(self, track_id, box):
        """
        Store track data.

        Args:
            track_id (int): object track id.
            box (list): object bounding box data
        """
        track = self.trk_history[track_id]
        bbox_center = (float((box[0] + box[2]) / 2), float((box[1] + box[3]) / 2))
        track.append(bbox_center)

        if len(track) > 30:
            track.pop(0)

        self.trk_pts = np.hstack(track).astype(np.int32).reshape((-1, 1, 2))
        return track

    def calculate_speed(self, trk_id, track):
        """
        Calculation of object speed.

        Args:
            trk_id (int): object track id.
            track (list): tracking history for tracks path drawing
        """

        for point in self.reg_pts:

            if not point[0][0] < track[-1][0] < point[1][0]:
                continue
            if point[1][1] - self.spdl_dist_thresh < track[-1][1] < point[1][1] + self.spdl_dist_thresh:
                direction = "known"

            elif point[0][1] - self.spdl_dist_thresh < track[-1][1] < point[0][1] + self.spdl_dist_thresh:
                direction = "known"

            else:
                direction = "unknown"

            if self.trk_previous_times[trk_id] != 0 and direction != "unknown" and trk_id not in self.trk_idslist:
                self.trk_idslist.append(trk_id)

                time_difference = time() - self.trk_previous_times[trk_id]
                if time_difference > 0:
                    dist_difference = np.abs(track[-1][1] - self.trk_previous_points[trk_id][1])
                    speed = dist_difference / time_difference
                    self.dist_data[trk_id] = speed

                    self.trk_previous_times[trk_id] = time()
                    self.trk_previous_points[trk_id] = track[-1]
                    return speed

        self.trk_previous_times[trk_id] = time()
        self.trk_previous_points[trk_id] = track[-1]
        return 0

    def estimate_speed(self, track):
        """
        Calculate object based on tracking data.

        Args:
            track: track obtained from the object tracking process.
        """
        self.box = track.bbox
        self.trk_id = track.track_id

        track_new = self.store_track_info(self.trk_id, self.box)

        if self.trk_id not in self.trk_previous_times:
            self.trk_previous_times[self.trk_id] = 0

        return_speed = self.calculate_speed(self.trk_id, track_new)

        return return_speed

if __name__ == "__main__":
    SpeedEstimator()

# %%
import os
import random
import cv2
import numpy as np
from ultralytics import YOLO

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

from drive.MyDrive.ECSE415.Final_Project.deep_sort.deep_sort.tracker import Tracker as DeepSortTracker
from drive.MyDrive.ECSE415.Final_Project.deep_sort.deep_sort.track import Track as DeepSortTrack
from drive.MyDrive.ECSE415.Final_Project.deep_sort.tools import generate_detections as gdet
from drive.MyDrive.ECSE415.Final_Project.deep_sort.deep_sort import nn_matching
from drive.MyDrive.ECSE415.Final_Project.deep_sort.deep_sort.detection import Detection

# Helper to pass the class_id along
class EnhancedDetection(Detection):
    def __init__(self, bbox, score, feature, class_id):
        super().__init__(bbox, score, feature)
        self.class_id = class_id

class EnhancedTrack(DeepSortTrack):
    def __init__(self, mean, covariance, track_id, n_init, max_age, feature, class_id):
        super().__init__(mean, covariance, track_id, n_init, max_age, feature)
        self.class_id = class_id              # Store object type

class EnhancedTracker(DeepSortTracker):
    def _initiate_track(self, detection):
        mean, covariance = self.kf.initiate(detection.to_xyah())
        self.tracks.append(EnhancedTrack(
            mean, covariance, self._next_id, self.n_init, self.max_age,
            detection.feature, detection.class_id))
        self._next_id += 1

# Assuming class names corresponding to the model's outputs
class_names = {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}

class Tracker:
    tracker = None
    encoder = None
    tracks = None

    def __init__(self):

        max_cosine_distance = 0.4
        nn_budget = None

        encoder_model_filename = '/content/drive/MyDrive/ECSE415/Final_Project/mars-small128.pb'

        metric = nn_matching.NearestNeighborDistanceMetric("cosine", max_cosine_distance, nn_budget)
        self.tracker = EnhancedTracker(metric)
        self.encoder = gdet.create_box_encoder(encoder_model_filename, batch_size=1)

    def update(self, frame, detections):

        if len(detections) == 0:
            self.tracker.predict()
            self.tracker.update([])
            self.update_tracks()
            return

        bboxes = np.asarray([d[:4] for d in detections])    # Extract bbox coordinates
        bboxes[:, 2:] = bboxes[:, 2:] - bboxes[:, 0:2]      # Convert coordinates to [x, y, w, h]
        scores = [d[4] for d in detections]
        class_ids = [d[5] for d in detections]              # Extract class IDs

        # Extract features using pre-trained encoder
        features = self.encoder(frame, bboxes)

        # Prepare detections for the tracker
        dets = []
        for bbox_id, bbox in enumerate(bboxes):
            det = EnhancedDetection(bbox, scores[bbox_id], features[bbox_id], class_ids[bbox_id])
            dets.append(det)

        # Update the tracker with the detections
        self.tracker.predict()
        self.tracker.update(dets)

        tracks = []
        for track in self.tracker.tracks:
            if not track.is_confirmed() or track.time_since_update > 1:
                continue
            bbox = track.to_tlbr()

            id = track.track_id

            obj_type = class_names[track.class_id]

            tracks.append(Track(id, bbox, obj_type))

        self.tracks = tracks


class Track:
    track_id = None
    bbox = None
    obj_type = None

    def __init__(self, id, bbox, obj_type):
        self.track_id = id
        self.bbox = bbox
        self.obj_type = obj_type


def calculate_filtered_mean(speeds, threshold=5):
    if not speeds:
        return 0
    mean_speed = np.mean(speeds)
    std_dev = np.std(speeds)
    filtered_speeds = [speed for speed in speeds if (mean_speed - threshold * std_dev <= speed <= mean_speed + threshold * std_dev)]
    return np.mean(filtered_speeds) if filtered_speeds else 0

# Modified function to process each video and count total people and cars
def process_video(video_path, video_out_path):

    cap = cv2.VideoCapture(video_path)
    ret, frame = cap.read()

    # Get the frames per second of the video
    fps = cap.get(cv2.CAP_PROP_FPS)

    cap_out = cv2.VideoWriter(video_out_path, cv2.VideoWriter_fourcc(*'MP4V'), cap.get(cv2.CAP_PROP_FPS),
                              (frame.shape[1], frame.shape[0]))

    model = YOLO("yolov8n.pt")

    w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    reg_pts = [[(0, 1000),(w, 1000)], [(0, 1050),(w, 1050)], [(0, 1135),(w, 1135)], [(0, 1220),(w, 1220)], [(0, 1370),(w, 1370)]]
    speed_obj = SpeedEstimator()
    speed_obj.set_args(reg_pts=reg_pts, spdl_dist_thresh=25)

    tracker = Tracker()

    colors = [(random.randint(0, 255), random.randint(0, 255), random.randint(0, 255)) for j in range(10)]

    detection_threshold = 0.5

    # Initialize the counter dictionary
    track_counts = {}

    # Dictionary to store object types
    obj_types = {}

    speed_history = defaultdict(list)

    prev_frame = None

    while ret:

        results = model(frame)

        for result in results:
            detections = []
            for r in result.boxes.data.tolist():
                x1, y1, x2, y2, score, class_id = r
                if score > detection_threshold:
                    detections.append([int(x1), int(y1), int(x2), int(y2), score, int(class_id)])

            tracker.update(frame, detections)

            for track in tracker.tracks:
                bbox = track.bbox
                x1, y1, x2, y2 = bbox
                track_id = track.track_id
                obj_type = track.obj_type  # Retrieve object type for this track

                # Update the count for this track ID
                track_counts[track_id] = track_counts.get(track_id, 0) + 1

                # Store object type based on track ID
                obj_types[track_id] = obj_type

                frame, speed = speed_obj.estimate_speed(frame, track)

                if speed != 0:
                    speed_history[track_id].append(speed)

                if speed_history[track_id]:  # Check if there's any speed recorded
                    newest_speed = speed_history[track_id][-1]  # Access the last speed recorded
                else:
                    newest_speed = 0  # Default speed if no speed is recorded

                # Loop through each tuple pair in reg_pts and draw each line
                for pt1, pt2 in reg_pts:
                    color = (0, 255, 0)  # Green color
                    thickness = 2  # Line thickness
                    cv2.line(frame, pt1, pt2, color, thickness)

                cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (colors[track_id % len(colors)]), 3)
                cv2.putText(frame, f"ID: {track_id} - Type: {obj_type} - Speed: {newest_speed:.2f} pixels/second", (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)

        cap_out.write(frame)
        prev_frame = frame.copy()
        ret, frame = cap.read()

    cap.release()
    cap_out.release()
    cv2.destroyAllWindows()

    # Initialize counters
    num_people = 0
    num_parked_cars = 0
    num_moving_cars = 0

    # Iterate over the tracks
    for track_id, count in track_counts.items():
        obj_type = obj_types[track_id]
        if len(speed_history[track_id]) > 0:  # Ensure there is speed data
            avg_speed = calculate_filtered_mean(speed_history[track_id], 5)  # Adjust threshold as needed
        else:
            avg_speed = 0  # Default to 0 if no speed data

        # Check object type and count accordingly
        if obj_type == 'person':
            num_people += 1
        elif obj_type == 'car' and count > 10:
            if 3 <= avg_speed <= 7:
                num_parked_cars += 1
            else:
                num_moving_cars += 1

        print(f"Track ID: {track_id} - Count: {count} - Type: {obj_types[track_id]} - Avg Speed: {avg_speed:.2f} pixels/second")

    return num_people, num_parked_cars, num_moving_cars
# Out:
# Mounted at /content/drive

# %%
num_people, num_parked_cars, num_moving_cars = process_video('/content/drive/MyDrive/ECSE415/Final_Project/mcgill_drive.mp4', '/content/drive/MyDrive/ECSE415/Final_Project/mcgill_drive_out.mp4')

# Print summary counts
print(f"Total number of people: {num_people}")
print(f"Total number of parked cars: {num_parked_cars}")
print(f"Total number of moving cars: {num_moving_cars}")
# Out:
# Ultralytics YOLOv8.0.33 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# 0: 384x640 6 cars, 7.7ms
# Speed: 0.4ms pre-process, 7.7ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 8.7ms
# Speed: 0.5ms pre-process, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 8.7ms
# Speed: 0.6ms pre-process, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 8.2ms
# Speed: 0.5ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 9.0ms
# Speed: 0.7ms pre-process, 9.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 10.4ms
# Speed: 0.7ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 10.0ms
# Speed: 0.7ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 11.0ms
# Speed: 0.6ms pre-process, 11.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.4ms
# Speed: 0.7ms pre-process, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 2 traffic lights, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 2 traffic lights, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 2 traffic lights, 11.4ms
# Speed: 0.6ms pre-process, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 truck, 1 traffic light, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 12.0ms
# Speed: 0.7ms pre-process, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 8.5ms
# Speed: 0.5ms pre-process, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 11.6ms
# Speed: 0.7ms pre-process, 11.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 12.1ms
# Speed: 0.6ms pre-process, 12.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 8.4ms
# Speed: 0.7ms pre-process, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 8.7ms
# Speed: 0.6ms pre-process, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 10.3ms
# Speed: 0.7ms pre-process, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 8.9ms
# Speed: 0.5ms pre-process, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 8.7ms
# Speed: 1.7ms pre-process, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 13.0ms
# Speed: 0.7ms pre-process, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 9.4ms
# Speed: 0.7ms pre-process, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 13.0ms
# Speed: 0.7ms pre-process, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 15.4ms
# Speed: 1.2ms pre-process, 15.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 11.0ms
# Speed: 0.6ms pre-process, 11.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 10.1ms
# Speed: 0.7ms pre-process, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 2 traffic lights, 8.2ms
# Speed: 0.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 traffic light, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 13.6ms
# Speed: 0.6ms pre-process, 13.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 truck, 9.1ms
# Speed: 0.7ms pre-process, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 8.9ms
# Speed: 0.7ms pre-process, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 truck, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 8.2ms
# Speed: 0.7ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 truck, 1 traffic light, 8.1ms
# Speed: 0.7ms pre-process, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 8.9ms
# Speed: 0.6ms pre-process, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 truck, 1 traffic light, 8.6ms
# Speed: 0.7ms pre-process, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 11.4ms
# Speed: 0.6ms pre-process, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 1 truck, 1 traffic light, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 1 bus, 1 traffic light, 13.4ms
# Speed: 0.6ms pre-process, 13.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 8.3ms
# Speed: 0.7ms pre-process, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 1 truck, 10.4ms
# Speed: 0.7ms pre-process, 10.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 1 fire hydrant, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 1 fire hydrant, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 traffic light, 11.4ms
# Speed: 0.6ms pre-process, 11.4ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 parking meter, 8.8ms
# Speed: 0.6ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 traffic light, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 13.2ms
# Speed: 0.7ms pre-process, 13.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 parking meter, 10.2ms
# Speed: 0.7ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 11.0ms
# Speed: 0.6ms pre-process, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 train, 12.0ms
# Speed: 0.6ms pre-process, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 train, 13.0ms
# Speed: 0.6ms pre-process, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 10.4ms
# Speed: 0.7ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 traffic light, 1 fire hydrant, 1 parking meter, 13.0ms
# Speed: 0.6ms pre-process, 13.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 1 fire hydrant, 11.3ms
# Speed: 0.6ms pre-process, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 2 traffic lights, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 traffic light, 1 fire hydrant, 13.3ms
# Speed: 0.6ms pre-process, 13.3ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 fire hydrant, 12.9ms
# Speed: 0.6ms pre-process, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 2 traffic lights, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 19.8ms
# Speed: 0.7ms pre-process, 19.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 traffic light, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 12.1ms
# Speed: 0.6ms pre-process, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 2 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 traffic light, 2 clocks, 17.1ms
# Speed: 0.6ms pre-process, 17.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 12.4ms
# Speed: 0.6ms pre-process, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 2 traffic lights, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 2 traffic lights, 8.3ms
# Speed: 0.5ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 12.9ms
# Speed: 0.6ms pre-process, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 11.2ms
# Speed: 0.6ms pre-process, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 traffic light, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 traffic light, 11.4ms
# Speed: 0.6ms pre-process, 11.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 traffic light, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 1 fire hydrant, 12.4ms
# Speed: 0.6ms pre-process, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 1 fire hydrant, 8.9ms
# Speed: 0.7ms pre-process, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 8.6ms
# Speed: 0.5ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 2 traffic lights, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 8.6ms
# Speed: 0.7ms pre-process, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 1 fire hydrant, 12.5ms
# Speed: 0.6ms pre-process, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 traffic light, 1 fire hydrant, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 1 fire hydrant, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 fire hydrant, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 9.1ms
# Speed: 0.5ms pre-process, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 2 traffic lights, 1 fire hydrant, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 2 traffic lights, 1 fire hydrant, 19.7ms
# Speed: 0.6ms pre-process, 19.7ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 1 fire hydrant, 8.2ms
# Speed: 0.5ms pre-process, 8.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 traffic light, 1 fire hydrant, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 1 fire hydrant, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 1 fire hydrant, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 2 traffic lights, 1 fire hydrant, 12.4ms
# Speed: 0.6ms pre-process, 12.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 1 fire hydrant, 8.1ms
# Speed: 0.5ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 1 fire hydrant, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 1 fire hydrant, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 2 traffic lights, 10.7ms
# Speed: 0.7ms pre-process, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 1 fire hydrant, 9.0ms
# Speed: 0.6ms pre-process, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 1 fire hydrant, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 traffic light, 24.9ms
# Speed: 0.6ms pre-process, 24.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 2 traffic lights, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 2 traffic lights, 10.4ms
# Speed: 0.8ms pre-process, 10.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 3 traffic lights, 1 fire hydrant, 11.9ms
# Speed: 0.6ms pre-process, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 1 fire hydrant, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 traffic light, 8.4ms
# Speed: 0.7ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 traffic light, 9.1ms
# Speed: 0.6ms pre-process, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 10.9ms
# Speed: 0.5ms pre-process, 10.9ms inference, 3.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 12.9ms
# Speed: 0.6ms pre-process, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 traffic light, 12.9ms
# Speed: 0.7ms pre-process, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 traffic light, 11.0ms
# Speed: 0.6ms pre-process, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 2 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 2 traffic lights, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 4 traffic lights, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 3 traffic lights, 12.4ms
# Speed: 0.6ms pre-process, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 3 traffic lights, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 traffic light, 9.3ms
# Speed: 0.7ms pre-process, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 3 cars, 2 traffic lights, 12.0ms
# Speed: 0.7ms pre-process, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 traffic light, 8.5ms
# Speed: 0.7ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 traffic light, 12.9ms
# Speed: 0.6ms pre-process, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 9.5ms
# Speed: 0.7ms pre-process, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.8ms
# Speed: 0.6ms pre-process, 8.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 1 boat, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 1 boat, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 12.7ms
# Speed: 0.7ms pre-process, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 8.4ms
# Speed: 0.7ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 truck, 1 bench, 12.8ms
# Speed: 0.6ms pre-process, 12.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 1 skateboard, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 2 traffic lights, 1 bench, 2 skateboards, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 skateboard, 9.2ms
# Speed: 0.7ms pre-process, 9.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 1 bench, 10.5ms
# Speed: 0.7ms pre-process, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 bench, 11.2ms
# Speed: 0.6ms pre-process, 11.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 skateboard, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 13.1ms
# Speed: 0.6ms pre-process, 13.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 bench, 2 skateboards, 8.4ms
# Speed: 0.5ms pre-process, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 5 cars, 1 bench, 24.5ms
# Speed: 0.6ms pre-process, 24.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 2 skateboards, 9.1ms
# Speed: 0.7ms pre-process, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 13.7ms
# Speed: 0.6ms pre-process, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 5 cars, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 4 cars, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 persons, 4 cars, 12.7ms
# Speed: 0.7ms pre-process, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 4 cars, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 4 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 4 cars, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 3 cars, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 persons, 3 cars, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 3 cars, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 3 cars, 1 skateboard, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 persons, 3 cars, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 persons, 4 cars, 1 traffic light, 11.0ms
# Speed: 0.6ms pre-process, 11.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 9.6ms
# Speed: 5.7ms pre-process, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 4 cars, 12.8ms
# Speed: 0.6ms pre-process, 12.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 15.3ms
# Speed: 0.6ms pre-process, 15.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 12.3ms
# Speed: 0.6ms pre-process, 12.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 4.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 9.8ms
# Speed: 0.7ms pre-process, 9.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 11.4ms
# Speed: 0.7ms pre-process, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 8.4ms
# Speed: 0.7ms pre-process, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 8.5ms
# Speed: 0.5ms pre-process, 8.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.0ms
# Speed: 0.6ms pre-process, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 8.1ms
# Speed: 0.5ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 9.5ms
# Speed: 0.6ms pre-process, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 10.1ms
# Speed: 1.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 8.3ms
# Speed: 0.7ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 24.3ms
# Speed: 0.6ms pre-process, 24.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 8.9ms
# Speed: 0.7ms pre-process, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 4 cars, 13.9ms
# Speed: 0.7ms pre-process, 13.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 persons, 5 cars, 13.8ms
# Speed: 0.6ms pre-process, 13.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 2 traffic lights, 7.9ms
# Speed: 0.6ms pre-process, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 9.5ms
# Speed: 0.6ms pre-process, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 5 cars, 1 traffic light, 12.9ms
# Speed: 0.7ms pre-process, 12.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 traffic light, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 4 cars, 9.3ms
# Speed: 0.6ms pre-process, 9.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 8.3ms
# Speed: 0.7ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 traffic light, 8.8ms
# Speed: 0.8ms pre-process, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 motorcycle, 1 traffic light, 13.0ms
# Speed: 0.6ms pre-process, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 traffic light, 1 skateboard, 12.3ms
# Speed: 0.6ms pre-process, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 5 cars, 11.8ms
# Speed: 0.6ms pre-process, 11.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 6 cars, 2 traffic lights, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 2 traffic lights, 10.4ms
# Speed: 0.7ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 7 cars, 3 traffic lights, 10.5ms
# Speed: 0.8ms pre-process, 10.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 5 cars, 2 traffic lights, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 5 cars, 1 traffic light, 9.0ms
# Speed: 0.7ms pre-process, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 4 cars, 2 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 1 bicycle, 5 cars, 1 traffic light, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bicycles, 5 cars, 1 traffic light, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 2 bicycles, 6 cars, 1 traffic light, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 5 cars, 2 traffic lights, 9.5ms
# Speed: 0.7ms pre-process, 9.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 7 cars, 2 traffic lights, 9.6ms
# Speed: 0.6ms pre-process, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 5 cars, 3 traffic lights, 12.6ms
# Speed: 0.7ms pre-process, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 1 bicycle, 5 cars, 3 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 3 traffic lights, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 4 traffic lights, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 5 traffic lights, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 3 traffic lights, 13.4ms
# Speed: 0.7ms pre-process, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 4 traffic lights, 13.3ms
# Speed: 0.6ms pre-process, 13.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 3 traffic lights, 11.2ms
# Speed: 0.6ms pre-process, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 6 traffic lights, 10.9ms
# Speed: 1.9ms pre-process, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 4 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 4 traffic lights, 21.2ms
# Speed: 0.6ms pre-process, 21.2ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 4 traffic lights, 11.8ms
# Speed: 0.6ms pre-process, 11.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 5 traffic lights, 11.6ms
# Speed: 0.7ms pre-process, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 3 traffic lights, 1 bench, 9.2ms
# Speed: 0.6ms pre-process, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 3 traffic lights, 8.2ms
# Speed: 0.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 4 traffic lights, 11.7ms
# Speed: 0.6ms pre-process, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 3 traffic lights, 12.6ms
# Speed: 0.6ms pre-process, 12.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 13.7ms
# Speed: 1.0ms pre-process, 13.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 9.6ms
# Speed: 0.7ms pre-process, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 2 traffic lights, 20.4ms
# Speed: 0.6ms pre-process, 20.4ms inference, 10.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 traffic light, 17.8ms
# Speed: 0.6ms pre-process, 17.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 13.0ms
# Speed: 0.7ms pre-process, 13.0ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 13.5ms
# Speed: 0.7ms pre-process, 13.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 8.6ms
# Speed: 0.7ms pre-process, 8.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.0ms
# Speed: 0.7ms pre-process, 8.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 8.5ms
# Speed: 0.7ms pre-process, 8.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.2ms
# Speed: 0.7ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 9.0ms
# Speed: 0.6ms pre-process, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 7.9ms
# Speed: 0.6ms pre-process, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.1ms
# Speed: 0.7ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 9.4ms
# Speed: 0.5ms pre-process, 9.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.2ms
# Speed: 0.7ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.9ms
# Speed: 0.6ms pre-process, 8.9ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 13.1ms
# Speed: 0.7ms pre-process, 13.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 9.8ms
# Speed: 0.7ms pre-process, 9.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.6ms
# Speed: 0.8ms pre-process, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 train, 12.5ms
# Speed: 0.6ms pre-process, 12.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 1 train, 9.4ms
# Speed: 0.7ms pre-process, 9.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 8.7ms
# Speed: 0.6ms pre-process, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.5ms
# Speed: 0.7ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 18.5ms
# Speed: 0.7ms pre-process, 18.5ms inference, 7.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 8.2ms
# Speed: 0.9ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 18.4ms
# Speed: 0.6ms pre-process, 18.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.7ms
# Speed: 0.7ms pre-process, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 8.2ms
# Speed: 0.5ms pre-process, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 18.6ms
# Speed: 3.6ms pre-process, 18.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 9.2ms
# Speed: 0.7ms pre-process, 9.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 9.3ms
# Speed: 0.6ms pre-process, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 13.5ms
# Speed: 0.7ms pre-process, 13.5ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 9.2ms
# Speed: 0.7ms pre-process, 9.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 13.6ms
# Speed: 0.7ms pre-process, 13.6ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 12.6ms
# Speed: 0.6ms pre-process, 12.6ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 12.7ms
# Speed: 0.6ms pre-process, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 9.9ms
# Speed: 0.7ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 12.3ms
# Speed: 0.6ms pre-process, 12.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 9.0ms
# Speed: 0.7ms pre-process, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 8.7ms
# Speed: 0.7ms pre-process, 8.7ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 10.6ms
# Speed: 0.8ms pre-process, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 8.9ms
# Speed: 0.6ms pre-process, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 12.4ms
# Speed: 0.6ms pre-process, 12.4ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 truck, 8.7ms
# Speed: 0.7ms pre-process, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 truck, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 8.8ms
# Speed: 0.6ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 12.9ms
# Speed: 0.6ms pre-process, 12.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 5 cars, 1 truck, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 9.0ms
# Speed: 0.7ms pre-process, 9.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 13.0ms
# Speed: 0.7ms pre-process, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 truck, 8.6ms
# Speed: 0.5ms pre-process, 8.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 truck, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 7.6ms
# Speed: 0.5ms pre-process, 7.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 9.3ms
# Speed: 0.6ms pre-process, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 11.2ms
# Speed: 0.7ms pre-process, 11.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 8.4ms
# Speed: 0.5ms pre-process, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 truck, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 9.5ms
# Speed: 0.7ms pre-process, 9.5ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 11.2ms
# Speed: 0.7ms pre-process, 11.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 9.1ms
# Speed: 0.6ms pre-process, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 1 fire hydrant, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# ...
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 train, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 train, 10.0ms
# Speed: 0.5ms pre-process, 10.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 train, 12.8ms
# Speed: 0.6ms pre-process, 12.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 train, 9.9ms
# Speed: 0.7ms pre-process, 9.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 1 train, 18.8ms
# Speed: 0.6ms pre-process, 18.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 19.3ms
# Speed: 0.6ms pre-process, 19.3ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 3 cars, 1 bus, 22.6ms
# Speed: 0.6ms pre-process, 22.6ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 20.8ms
# Speed: 0.7ms pre-process, 20.8ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 13.7ms
# Speed: 0.6ms pre-process, 13.7ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 10.1ms
# Speed: 1.3ms pre-process, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 10.2ms
# Speed: 0.7ms pre-process, 10.2ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 11.1ms
# Speed: 0.5ms pre-process, 11.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 11.7ms
# Speed: 0.7ms pre-process, 11.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 11.9ms
# Speed: 0.6ms pre-process, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 8.9ms
# Speed: 0.6ms pre-process, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 cars, 1 bus, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 cars, 1 bus, 1 train, 1 truck, 9.0ms
# Speed: 0.6ms pre-process, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 3 cars, 2 buss, 18.5ms
# Speed: 0.6ms pre-process, 18.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 1 truck, 19.2ms
# Speed: 5.2ms pre-process, 19.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 17.5ms
# Speed: 0.6ms pre-process, 17.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 18.3ms
# Speed: 0.7ms pre-process, 18.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 9.1ms
# Speed: 0.7ms pre-process, 9.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 bus, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 16.5ms
# Speed: 0.7ms pre-process, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 12.7ms
# Speed: 0.6ms pre-process, 12.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 8.6ms
# Speed: 1.9ms pre-process, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 19.3ms
# Speed: 0.6ms pre-process, 19.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 truck, 15.4ms
# Speed: 0.6ms pre-process, 15.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 18.4ms
# Speed: 0.6ms pre-process, 18.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 15.4ms
# Speed: 0.7ms pre-process, 15.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 traffic light, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 8.2ms
# Speed: 0.5ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 bus, 12.8ms
# Speed: 0.6ms pre-process, 12.8ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 bus, 13.1ms
# Speed: 0.6ms pre-process, 13.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 8.8ms
# Speed: 0.6ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 16.5ms
# Speed: 0.6ms pre-process, 16.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 8.4ms
# Speed: 0.5ms pre-process, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 truck, 9.3ms
# Speed: 0.6ms pre-process, 9.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 9 cars, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 8.6ms
# Speed: 0.7ms pre-process, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 8.2ms
# Speed: 0.7ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 10.6ms
# Speed: 0.7ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 10.6ms
# Speed: 3.1ms pre-process, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 traffic light, 8.9ms
# Speed: 0.6ms pre-process, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
# Track ID: 1 - Count: 61 - Type: car - Avg Speed: 0.75 pixels/second
# Track ID: 2 - Count: 62 - Type: car - Avg Speed: 6.42 pixels/second
# Track ID: 3 - Count: 987 - Type: car - Avg Speed: 3.81 pixels/second
# Track ID: 4 - Count: 95 - Type: car - Avg Speed: 2.22 pixels/second
# Track ID: 5 - Count: 68 - Type: car - Avg Speed: 16.03 pixels/second
# Track ID: 8 - Count: 2 - Type: car - Avg Speed: 0.82 pixels/second
# Track ID: 9 - Count: 76 - Type: car - Avg Speed: 0.54 pixels/second
# Track ID: 11 - Count: 89 - Type: car - Avg Speed: 10.98 pixels/second
# Track ID: 13 - Count: 2 - Type: car - Avg Speed: 25.50 pixels/second
# Track ID: 17 - Count: 16 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 18 - Count: 10 - Type: person - Avg Speed: 1.03 pixels/second
# Track ID: 20 - Count: 84 - Type: car - Avg Speed: 0.28 pixels/second
# Track ID: 22 - Count: 42 - Type: car - Avg Speed: 9.43 pixels/second
# Track ID: 37 - Count: 69 - Type: car - Avg Speed: 10.10 pixels/second
# Track ID: 38 - Count: 8 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 39 - Count: 42 - Type: person - Avg Speed: 3.54 pixels/second
# Track ID: 40 - Count: 2 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 44 - Count: 20 - Type: person - Avg Speed: 6.58 pixels/second
# Track ID: 47 - Count: 62 - Type: person - Avg Speed: 2.54 pixels/second
# Track ID: 48 - Count: 34 - Type: person - Avg Speed: 7.74 pixels/second
# Track ID: 52 - Count: 39 - Type: car - Avg Speed: 1.36 pixels/second
# Track ID: 53 - Count: 115 - Type: car - Avg Speed: 4.72 pixels/second
# Track ID: 58 - Count: 73 - Type: car - Avg Speed: 2.52 pixels/second
# Track ID: 68 - Count: 131 - Type: car - Avg Speed: 11.35 pixels/second
# Track ID: 74 - Count: 21 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 75 - Count: 4 - Type: bicycle - Avg Speed: 0.00 pixels/second
# Track ID: 81 - Count: 15 - Type: person - Avg Speed: 2.83 pixels/second
# Track ID: 83 - Count: 4 - Type: person - Avg Speed: 28.30 pixels/second
# Track ID: 84 - Count: 12 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 87 - Count: 2 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 94 - Count: 15 - Type: person - Avg Speed: 2.13 pixels/second
# Track ID: 97 - Count: 26 - Type: person - Avg Speed: 3.12 pixels/second
# Track ID: 98 - Count: 28 - Type: truck - Avg Speed: 8.33 pixels/second
# Track ID: 101 - Count: 6 - Type: truck - Avg Speed: 19.31 pixels/second
# Track ID: 102 - Count: 35 - Type: car - Avg Speed: 1.52 pixels/second
# Track ID: 103 - Count: 102 - Type: car - Avg Speed: 9.13 pixels/second
# Track ID: 105 - Count: 11 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 109 - Count: 10 - Type: fire hydrant - Avg Speed: 28.05 pixels/second
# Track ID: 113 - Count: 36 - Type: car - Avg Speed: 11.14 pixels/second
# Track ID: 119 - Count: 2 - Type: bus - Avg Speed: 12.27 pixels/second
# Track ID: 124 - Count: 16 - Type: car - Avg Speed: 15.80 pixels/second
# Track ID: 125 - Count: 2 - Type: truck - Avg Speed: 0.00 pixels/second
# Track ID: 129 - Count: 3 - Type: person - Avg Speed: 16.62 pixels/second
# Track ID: 130 - Count: 7 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 137 - Count: 29 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 140 - Count: 9 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 141 - Count: 34 - Type: person - Avg Speed: 29.64 pixels/second
# Track ID: 142 - Count: 107 - Type: car - Avg Speed: 0.32 pixels/second
# Track ID: 143 - Count: 62 - Type: car - Avg Speed: 8.80 pixels/second
# Track ID: 144 - Count: 16 - Type: fire hydrant - Avg Speed: 3.20 pixels/second
# Track ID: 149 - Count: 9 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 150 - Count: 70 - Type: car - Avg Speed: 1.48 pixels/second
# Track ID: 153 - Count: 5 - Type: bicycle - Avg Speed: 0.00 pixels/second
# Track ID: 157 - Count: 17 - Type: car - Avg Speed: 5.87 pixels/second
# Track ID: 160 - Count: 4 - Type: bicycle - Avg Speed: 21.49 pixels/second
# Track ID: 163 - Count: 79 - Type: car - Avg Speed: 18.97 pixels/second
# Track ID: 166 - Count: 11 - Type: person - Avg Speed: 28.31 pixels/second
# Track ID: 169 - Count: 121 - Type: car - Avg Speed: 4.21 pixels/second
# Track ID: 171 - Count: 2 - Type: person - Avg Speed: 5.21 pixels/second
# Track ID: 172 - Count: 43 - Type: car - Avg Speed: 7.76 pixels/second
# Track ID: 188 - Count: 26 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 195 - Count: 65 - Type: car - Avg Speed: 4.42 pixels/second
# Track ID: 201 - Count: 11 - Type: car - Avg Speed: 3.54 pixels/second
# Track ID: 203 - Count: 41 - Type: car - Avg Speed: 17.46 pixels/second
# Track ID: 207 - Count: 16 - Type: car - Avg Speed: 3.74 pixels/second
# Track ID: 213 - Count: 62 - Type: car - Avg Speed: 3.41 pixels/second
# Track ID: 214 - Count: 69 - Type: car - Avg Speed: 1.90 pixels/second
# Track ID: 215 - Count: 6 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 228 - Count: 40 - Type: car - Avg Speed: 5.88 pixels/second
# Track ID: 230 - Count: 50 - Type: car - Avg Speed: 4.44 pixels/second
# Track ID: 232 - Count: 16 - Type: person - Avg Speed: 4.83 pixels/second
# Track ID: 244 - Count: 18 - Type: car - Avg Speed: 1.51 pixels/second
# Track ID: 248 - Count: 3 - Type: motorcycle - Avg Speed: 73.46 pixels/second
# Track ID: 252 - Count: 18 - Type: fire hydrant - Avg Speed: 23.73 pixels/second
# Track ID: 253 - Count: 42 - Type: car - Avg Speed: 1.77 pixels/second
# Track ID: 257 - Count: 6 - Type: person - Avg Speed: 14.49 pixels/second
# Track ID: 258 - Count: 30 - Type: car - Avg Speed: 10.99 pixels/second
# Track ID: 259 - Count: 32 - Type: person - Avg Speed: 1.07 pixels/second
# Track ID: 263 - Count: 10 - Type: person - Avg Speed: 6.56 pixels/second
# Track ID: 264 - Count: 41 - Type: car - Avg Speed: 3.14 pixels/second
# Track ID: 270 - Count: 19 - Type: car - Avg Speed: 11.77 pixels/second
# Track ID: 271 - Count: 61 - Type: car - Avg Speed: 6.00 pixels/second
# Track ID: 274 - Count: 2 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 275 - Count: 8 - Type: person - Avg Speed: 22.47 pixels/second
# Track ID: 281 - Count: 58 - Type: car - Avg Speed: 0.94 pixels/second
# Track ID: 287 - Count: 26 - Type: car - Avg Speed: 15.82 pixels/second
# Track ID: 289 - Count: 4 - Type: car - Avg Speed: 24.48 pixels/second
# Track ID: 296 - Count: 9 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 300 - Count: 4 - Type: car - Avg Speed: 7.74 pixels/second
# Track ID: 304 - Count: 11 - Type: car - Avg Speed: 0.02 pixels/second
# Track ID: 306 - Count: 45 - Type: car - Avg Speed: 0.36 pixels/second
# Track ID: 310 - Count: 21 - Type: person - Avg Speed: 4.65 pixels/second
# Track ID: 312 - Count: 9 - Type: person - Avg Speed: 28.40 pixels/second
# Track ID: 323 - Count: 46 - Type: car - Avg Speed: 12.71 pixels/second
# Track ID: 324 - Count: 20 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 332 - Count: 26 - Type: person - Avg Speed: 15.92 pixels/second
# Track ID: 340 - Count: 2 - Type: person - Avg Speed: 10.90 pixels/second
# Track ID: 342 - Count: 64 - Type: car - Avg Speed: 6.24 pixels/second
# Track ID: 343 - Count: 46 - Type: bus - Avg Speed: 0.00 pixels/second
# Track ID: 347 - Count: 17 - Type: car - Avg Speed: 2.20 pixels/second
# Track ID: 348 - Count: 6 - Type: person - Avg Speed: 18.07 pixels/second
# Track ID: 351 - Count: 21 - Type: person - Avg Speed: 8.37 pixels/second
# Track ID: 352 - Count: 2 - Type: car - Avg Speed: 4.93 pixels/second
# Track ID: 355 - Count: 19 - Type: car - Avg Speed: 4.82 pixels/second
# Track ID: 356 - Count: 19 - Type: car - Avg Speed: 1.21 pixels/second
# Track ID: 358 - Count: 3 - Type: car - Avg Speed: 2.03 pixels/second
# Track ID: 360 - Count: 18 - Type: car - Avg Speed: 28.24 pixels/second
# Track ID: 363 - Count: 13 - Type: car - Avg Speed: 10.35 pixels/second
# Track ID: 364 - Count: 3 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 365 - Count: 5 - Type: car - Avg Speed: 2.08 pixels/second
# Total number of people: 25
# Total number of parked cars: 15
# Total number of moving cars: 37

# %%
num_people, num_parked_cars, num_moving_cars = process_video('/content/drive/MyDrive/ECSE415/Final_Project/st-catherines_drive.mp4', '/content/drive/MyDrive/ECSE415/Final_Project/st-catherines_drive_out.mp4')

# Print summary counts
print(f"Total number of people: {num_people}")
print(f"Total number of parked cars: {num_parked_cars}")
print(f"Total number of moving cars: {num_moving_cars}")
# Out:
# Ultralytics YOLOv8.0.33 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 8.1ms
# Speed: 0.4ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 8.0ms
# Speed: 0.7ms pre-process, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 8.6ms
# Speed: 0.5ms pre-process, 8.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 1 traffic light, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 8.7ms
# Speed: 0.6ms pre-process, 8.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 9.4ms
# Speed: 0.6ms pre-process, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 7 cars, 1 bus, 1 truck, 13.2ms
# Speed: 0.7ms pre-process, 13.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 bus, 1 truck, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 truck, 9.6ms
# Speed: 0.7ms pre-process, 9.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 truck, 9.0ms
# Speed: 0.7ms pre-process, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 bus, 1 truck, 9.6ms
# Speed: 0.6ms pre-process, 9.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 1 truck, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 1 bicycle, 10 cars, 1 motorcycle, 1 bus, 1 truck, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 motorcycle, 1 bus, 1 truck, 13.2ms
# Speed: 3.2ms pre-process, 13.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 1 bus, 1 truck, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 motorcycle, 1 bus, 1 truck, 9.1ms
# Speed: 0.7ms pre-process, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 2 motorcycles, 1 bus, 1 truck, 13.0ms
# Speed: 0.6ms pre-process, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 motorcycle, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 motorcycle, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bicycle, 9 cars, 1 motorcycle, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 9.8ms
# Speed: 0.5ms pre-process, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 1 bicycle, 8 cars, 1 motorcycle, 1 bus, 1 truck, 9.4ms
# Speed: 0.6ms pre-process, 9.4ms inference, 4.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bicycles, 7 cars, 1 truck, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 3 bicycles, 7 cars, 1 truck, 10.7ms
# Speed: 0.7ms pre-process, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 truck, 13.9ms
# Speed: 0.7ms pre-process, 13.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 7 cars, 1 truck, 1 traffic light, 12.0ms
# Speed: 0.6ms pre-process, 12.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 truck, 15.3ms
# Speed: 0.6ms pre-process, 15.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 8 cars, 1 truck, 11.3ms
# Speed: 0.6ms pre-process, 11.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 9 cars, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 8 cars, 1 truck, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 3.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 8 cars, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 10 cars, 1 bus, 1 truck, 14.1ms
# Speed: 0.6ms pre-process, 14.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 7 cars, 1 truck, 1 traffic light, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 8 cars, 1 truck, 1 traffic light, 13.6ms
# Speed: 0.8ms pre-process, 13.6ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 8 cars, 1 truck, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 8 cars, 1 truck, 13.4ms
# Speed: 0.6ms pre-process, 13.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 8 cars, 1 truck, 18.9ms
# Speed: 0.6ms pre-process, 18.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 truck, 11.0ms
# Speed: 0.7ms pre-process, 11.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 truck, 1 traffic light, 12.6ms
# Speed: 0.7ms pre-process, 12.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 7 cars, 1 truck, 14.2ms
# Speed: 0.6ms pre-process, 14.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 7 cars, 1 truck, 9.8ms
# Speed: 1.3ms pre-process, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 bus, 1 truck, 11.6ms
# Speed: 0.7ms pre-process, 11.6ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 bus, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 bicycles, 5 cars, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 5 cars, 1 bus, 1 truck, 14.1ms
# Speed: 0.6ms pre-process, 14.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 2 bicycles, 5 cars, 1 truck, 13.0ms
# Speed: 0.6ms pre-process, 13.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 bicycles, 5 cars, 1 bus, 1 truck, 15.9ms
# Speed: 0.6ms pre-process, 15.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 5 cars, 1 bus, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 bus, 1 truck, 1 traffic light, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 5 cars, 1 bus, 1 truck, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 5 cars, 1 truck, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 6 cars, 1 truck, 12.6ms
# Speed: 0.6ms pre-process, 12.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 5 cars, 1 truck, 11.8ms
# Speed: 0.6ms pre-process, 11.8ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 5 cars, 1 bus, 1 truck, 10.2ms
# Speed: 1.3ms pre-process, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 5 cars, 1 bus, 1 truck, 8.1ms
# Speed: 0.7ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 5 cars, 1 bus, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 6 cars, 1 truck, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 6 cars, 1 truck, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 7 cars, 1 truck, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 6 cars, 1 truck, 1 traffic light, 11.7ms
# Speed: 0.7ms pre-process, 11.7ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 7 cars, 1 truck, 1 traffic light, 8.8ms
# Speed: 0.6ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 9 cars, 1 truck, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 bicycles, 9 cars, 1 truck, 11.7ms
# Speed: 0.6ms pre-process, 11.7ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 7 cars, 1 truck, 11.3ms
# Speed: 0.6ms pre-process, 11.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 7 cars, 1 truck, 12.2ms
# Speed: 1.1ms pre-process, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 6 cars, 1 truck, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 7 cars, 1 truck, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 bicycle, 9 cars, 1 truck, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 8.6ms
# Speed: 1.3ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 truck, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 9.8ms
# Speed: 1.3ms pre-process, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 truck, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 12.8ms
# Speed: 0.7ms pre-process, 12.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 12.3ms
# Speed: 0.7ms pre-process, 12.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 truck, 1 bench, 13.1ms
# Speed: 0.6ms pre-process, 13.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 1 traffic light, 9.5ms
# Speed: 0.7ms pre-process, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 truck, 12.5ms
# Speed: 0.8ms pre-process, 12.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 13.3ms
# Speed: 0.7ms pre-process, 13.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 14.3ms
# Speed: 0.6ms pre-process, 14.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 2 trucks, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 2 trucks, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 bus, 2 trucks, 21.5ms
# Speed: 0.6ms pre-process, 21.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 6 cars, 1 bus, 2 trucks, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 3 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 1 traffic light, 9.8ms
# Speed: 1.3ms pre-process, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 1 traffic light, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 12.0ms
# Speed: 0.6ms pre-process, 12.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 1 truck, 9.6ms
# Speed: 0.7ms pre-process, 9.6ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 8.0ms
# Speed: 0.5ms pre-process, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 1 truck, 8.2ms
# Speed: 0.5ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 1 truck, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 12.3ms
# Speed: 0.6ms pre-process, 12.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 11.9ms
# Speed: 0.6ms pre-process, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 11.1ms
# Speed: 0.7ms pre-process, 11.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 10.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 21.5ms
# Speed: 1.7ms pre-process, 21.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 2 trucks, 8.0ms
# Speed: 0.5ms pre-process, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 8.2ms
# Speed: 1.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 12.1ms
# Speed: 0.6ms pre-process, 12.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 12.7ms
# Speed: 0.7ms pre-process, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 7 cars, 1 bus, 1 truck, 9.9ms
# Speed: 0.7ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 12.6ms
# Speed: 0.6ms pre-process, 12.6ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 1 truck, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 4.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 1 truck, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 1 bench, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 1 bench, 9.4ms
# Speed: 0.6ms pre-process, 9.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 8.7ms
# Speed: 0.6ms pre-process, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 1 bench, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 2 trucks, 1 bench, 12.1ms
# Speed: 0.6ms pre-process, 12.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 12.7ms
# Speed: 0.6ms pre-process, 12.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 8.0ms
# Speed: 0.5ms pre-process, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 truck, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 2 trucks, 9.5ms
# Speed: 0.6ms pre-process, 9.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 2 trucks, 13.5ms
# Speed: 0.6ms pre-process, 13.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.7ms pre-process, 10.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 1 truck, 8.0ms
# Speed: 0.5ms pre-process, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 1 truck, 12.5ms
# Speed: 0.6ms pre-process, 12.5ms inference, 10.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 bus, 1 truck, 22.5ms
# Speed: 0.6ms pre-process, 22.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 11 cars, 1 bus, 1 truck, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 8 cars, 1 bus, 1 truck, 12.8ms
# Speed: 0.6ms pre-process, 12.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 6 cars, 1 bus, 1 truck, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 6 cars, 1 bus, 1 truck, 14.3ms
# Speed: 0.7ms pre-process, 14.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 persons, 7 cars, 1 bus, 1 truck, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 11 cars, 1 bus, 1 truck, 17.6ms
# Speed: 0.6ms pre-process, 17.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 bus, 2 trucks, 17.4ms
# Speed: 0.6ms pre-process, 17.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 1 truck, 8.2ms
# Speed: 0.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 traffic light, 16.9ms
# Speed: 0.6ms pre-process, 16.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 10 cars, 1 bus, 1 truck, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 3 trucks, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 1 fire hydrant, 10.1ms
# Speed: 0.7ms pre-process, 10.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 2 trucks, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 1 truck, 18.5ms
# Speed: 4.6ms pre-process, 18.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 1 truck, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 10 cars, 1 bus, 1 truck, 11.7ms
# Speed: 0.6ms pre-process, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 9 cars, 1 bus, 1 truck, 10.7ms
# Speed: 0.7ms pre-process, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 10 cars, 1 bus, 1 truck, 14.3ms
# Speed: 0.9ms pre-process, 14.3ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 10 cars, 1 bus, 1 truck, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 13.7ms
# Speed: 0.6ms pre-process, 13.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 11 cars, 1 bus, 9.1ms
# Speed: 0.6ms pre-process, 9.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 8 cars, 1 bus, 1 truck, 1 clock, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 10 cars, 1 bus, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 bus, 1 truck, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 10 cars, 1 bus, 1 truck, 1 traffic light, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 11 cars, 1 bus, 1 truck, 18.4ms
# Speed: 0.6ms pre-process, 18.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 bus, 1 truck, 1 traffic light, 10.2ms
# Speed: 0.7ms pre-process, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 10 cars, 1 bus, 1 truck, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 12.8ms
# Speed: 0.6ms pre-process, 12.8ms inference, 10.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 15.6ms
# Speed: 0.6ms pre-process, 15.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 2 trucks, 30.1ms
# Speed: 1.4ms pre-process, 30.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 8.4ms
# Speed: 0.7ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 26.4ms
# Speed: 0.6ms pre-process, 26.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 8.2ms
# Speed: 0.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 truck, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 14.5ms
# Speed: 0.6ms pre-process, 14.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 10.6ms
# Speed: 0.7ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 18.4ms
# Speed: 0.6ms pre-process, 18.4ms inference, 7.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 truck, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 12.1ms
# Speed: 0.6ms pre-process, 12.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 8.3ms
# Speed: 0.5ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 12.9ms
# Speed: 0.6ms pre-process, 12.9ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 2 trucks, 8.0ms
# Speed: 0.6ms pre-process, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 3 trucks, 11.9ms
# Speed: 0.6ms pre-process, 11.9ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 11 cars, 1 bus, 1 truck, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 1 truck, 8.3ms
# Speed: 0.5ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 1 truck, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 bus, 1 truck, 7.9ms
# Speed: 0.5ms pre-process, 7.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 1 truck, 14.4ms
# Speed: 0.6ms pre-process, 14.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 9 cars, 1 bus, 2 trucks, 11.9ms
# Speed: 0.6ms pre-process, 11.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 10 cars, 1 bus, 2 trucks, 19.5ms
# Speed: 0.6ms pre-process, 19.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 2 trucks, 8.2ms
# Speed: 0.7ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 2 trucks, 8.2ms
# Speed: 0.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 2 trucks, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 bus, 2 trucks, 17.5ms
# Speed: 0.6ms pre-process, 17.5ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 2 trucks, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 2 trucks, 8.2ms
# Speed: 0.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 2 trucks, 11.5ms
# Speed: 0.6ms pre-process, 11.5ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 3 trucks, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 10 cars, 1 bus, 2 trucks, 8.0ms
# Speed: 0.6ms pre-process, 8.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 2 trucks, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 bus, 2 trucks, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 8 cars, 1 bus, 3 trucks, 22.9ms
# Speed: 0.6ms pre-process, 22.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 persons, 10 cars, 2 buss, 2 trucks, 8.1ms
# Speed: 0.5ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 bus, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 2 buss, 2 trucks, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 12 cars, 1 bus, 1 truck, 12.3ms
# Speed: 0.6ms pre-process, 12.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 8.0ms
# Speed: 0.5ms pre-process, 8.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 13 cars, 1 bus, 1 truck, 11.7ms
# Speed: 0.6ms pre-process, 11.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 13 cars, 1 bus, 1 truck, 8.3ms
# Speed: 0.5ms pre-process, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 23.0ms
# Speed: 0.7ms pre-process, 23.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 8.9ms
# Speed: 0.6ms pre-process, 8.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 13 cars, 1 bus, 1 truck, 7.8ms
# Speed: 0.5ms pre-process, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 14.0ms
# Speed: 0.6ms pre-process, 14.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 12 cars, 1 bus, 1 truck, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 12 cars, 1 truck, 19.3ms
# Speed: 0.6ms pre-process, 19.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 9.5ms
# Speed: 0.6ms pre-process, 9.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 bus, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 5.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 11.2ms
# Speed: 0.6ms pre-process, 11.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 10.2ms
# Speed: 0.7ms pre-process, 10.2ms inference, 9.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 truck, 11.7ms
# Speed: 0.6ms pre-process, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 13 cars, 1 bus, 1 truck, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 13 cars, 1 bus, 1 truck, 12.5ms
# Speed: 0.7ms pre-process, 12.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 15 cars, 1 truck, 10.4ms
# Speed: 0.6ms pre-process, 10.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 bus, 1 truck, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 13 cars, 1 truck, 8.2ms
# Speed: 0.5ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 13 cars, 1 truck, 7.8ms
# Speed: 0.9ms pre-process, 7.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 12 cars, 1 truck, 15.0ms
# Speed: 0.7ms pre-process, 15.0ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 10 cars, 1 bus, 1 truck, 22.5ms
# Speed: 0.6ms pre-process, 22.5ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 9 cars, 1 bus, 9.0ms
# Speed: 0.7ms pre-process, 9.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 8.7ms
# Speed: 0.7ms pre-process, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 12 cars, 1 bus, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 traffic light, 19.4ms
# Speed: 0.6ms pre-process, 19.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 8.9ms
# Speed: 0.5ms pre-process, 8.9ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 traffic light, 21.0ms
# Speed: 0.6ms pre-process, 21.0ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 traffic light, 8.4ms
# Speed: 0.5ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 12 cars, 1 bus, 13.4ms
# Speed: 0.7ms pre-process, 13.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 truck, 9.0ms
# Speed: 0.7ms pre-process, 9.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 12 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 truck, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 12 cars, 1 truck, 8.3ms
# Speed: 0.6ms pre-process, 8.3ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 truck, 1 traffic light, 8.8ms
# Speed: 0.7ms pre-process, 8.8ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 truck, 2 traffic lights, 8.6ms
# Speed: 0.6ms pre-process, 8.6ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 11 cars, 1 truck, 3 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 truck, 2 traffic lights, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 12 cars, 1 bus, 1 truck, 2 traffic lights, 23.6ms
# Speed: 0.6ms pre-process, 23.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 bus, 1 truck, 3 traffic lights, 13.4ms
# Speed: 0.6ms pre-process, 13.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 11 cars, 1 truck, 2 traffic lights, 10.2ms
# Speed: 0.7ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 13 cars, 1 bus, 1 truck, 2 traffic lights, 8.7ms
# Speed: 0.5ms pre-process, 8.7ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 truck, 2 traffic lights, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 1 traffic light, 11.2ms
# Speed: 0.6ms pre-process, 11.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 4 traffic lights, 20.0ms
# Speed: 0.6ms pre-process, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 2 traffic lights, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 1 traffic light, 19.1ms
# Speed: 0.6ms pre-process, 19.1ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 2 traffic lights, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 3 traffic lights, 12.4ms
# Speed: 0.7ms pre-process, 12.4ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 traffic light, 13.3ms
# Speed: 0.7ms pre-process, 13.3ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 1 traffic light, 13.2ms
# Speed: 0.6ms pre-process, 13.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 1 traffic light, 8.4ms
# Speed: 0.6ms pre-process, 8.4ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 1 traffic light, 8.2ms
# Speed: 0.6ms pre-process, 8.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 1 traffic light, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 1 traffic light, 12.2ms
# Speed: 0.6ms pre-process, 12.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 10 cars, 1 bus, 1 truck, 8.2ms
# Speed: 0.7ms pre-process, 8.2ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 bus, 1 truck, 2 traffic lights, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 1 truck, 1 traffic light, 13.2ms
# Speed: 0.6ms pre-process, 13.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 bus, 9.9ms
# Speed: 0.6ms pre-process, 9.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 bus, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 truck, 11.4ms
# Speed: 0.6ms pre-process, 11.4ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 truck, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 8 cars, 1 truck, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 9 cars, 1 truck, 11.7ms
# Speed: 0.6ms pre-process, 11.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 9 cars, 1 truck, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 21.3ms
# Speed: 0.6ms pre-process, 21.3ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 16.2ms
# Speed: 11.8ms pre-process, 16.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 7.9ms
# Speed: 0.6ms pre-process, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 8.4ms
# Speed: 0.8ms pre-process, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 7.9ms
# Speed: 0.6ms pre-process, 7.9ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 8 cars, 1 truck, 1 traffic light, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 truck, 1 traffic light, 13.0ms
# Speed: 0.7ms pre-process, 13.0ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 7 cars, 1 bus, 1 truck, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 20.8ms
# Speed: 1.1ms pre-process, 20.8ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 1 truck, 1 traffic light, 8.9ms
# Speed: 0.7ms pre-process, 8.9ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 bus, 1 truck, 1 traffic light, 9.9ms
# Speed: 5.0ms pre-process, 9.9ms inference, 7.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 1 traffic light, 1 bench, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 truck, 1 bench, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 6 cars, 1 bus, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 1 bench, 10.5ms
# Speed: 0.9ms pre-process, 10.5ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 1 bus, 10.7ms
# Speed: 2.5ms pre-process, 10.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 1 bus, 11.6ms
# Speed: 0.6ms pre-process, 11.6ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 10.0ms
# Speed: 0.6ms pre-process, 10.0ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 9.5ms
# Speed: 0.7ms pre-process, 9.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 1 bus, 1 truck, 10.6ms
# Speed: 0.6ms pre-process, 10.6ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 12.2ms
# Speed: 0.8ms pre-process, 12.2ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 8.5ms
# Speed: 0.7ms pre-process, 8.5ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 7.8ms
# Speed: 0.6ms pre-process, 7.8ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 persons, 4 cars, 1 bus, 1 truck, 14.9ms
# Speed: 0.6ms pre-process, 14.9ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 1 truck, 10.3ms
# Speed: 0.6ms pre-process, 10.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 5 cars, 1 bus, 9.8ms
# Speed: 0.6ms pre-process, 9.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 1 bus, 1 truck, 19.3ms
# Speed: 0.6ms pre-process, 19.3ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 8.1ms
# Speed: 0.6ms pre-process, 8.1ms inference, 3.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 6 cars, 1 bus, 1 truck, 9.7ms
# Speed: 0.6ms pre-process, 9.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 7 cars, 1 bus, 1 truck, 11.9ms
# Speed: 0.6ms pre-process, 11.9ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 1 bus, 1 truck, 10.2ms
# Speed: 0.6ms pre-process, 10.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 7 cars, 1 bus, 1 truck, 9.7ms
# ...
#
# 0: 384x640 1 person, 5 cars, 21.2ms
# Speed: 0.7ms pre-process, 21.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.2ms
# Speed: 1.0ms pre-process, 8.2ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 11.4ms
# Speed: 0.6ms pre-process, 11.4ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 6 cars, 8.8ms
# Speed: 0.6ms pre-process, 8.8ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 8.5ms
# Speed: 0.5ms pre-process, 8.5ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 13.0ms
# Speed: 0.6ms pre-process, 13.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 18.9ms
# Speed: 0.6ms pre-process, 18.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 9.2ms
# Speed: 0.6ms pre-process, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 10.7ms
# Speed: 0.6ms pre-process, 10.7ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 9.3ms
# Speed: 1.8ms pre-process, 9.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 14.5ms
# Speed: 0.6ms pre-process, 14.5ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 8.5ms
# Speed: 0.6ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 19.7ms
# Speed: 0.6ms pre-process, 19.7ms inference, 2.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 12.2ms
# Speed: 0.7ms pre-process, 12.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 10.9ms
# Speed: 0.6ms pre-process, 10.9ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 12.1ms
# Speed: 0.7ms pre-process, 12.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 24.2ms
# Speed: 0.6ms pre-process, 24.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 8.5ms
# Speed: 0.7ms pre-process, 8.5ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 10.1ms
# Speed: 0.6ms pre-process, 10.1ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 cars, 9.6ms
# Speed: 0.7ms pre-process, 9.6ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 19.2ms
# Speed: 0.6ms pre-process, 19.2ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 5 cars, 9.1ms
# Speed: 0.6ms pre-process, 9.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 20.0ms
# Speed: 0.6ms pre-process, 20.0ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 11.1ms
# Speed: 0.6ms pre-process, 11.1ms inference, 2.1ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 4 cars, 10.5ms
# Speed: 0.6ms pre-process, 10.5ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 3 cars, 9.2ms
# Speed: 0.7ms pre-process, 9.2ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 13.1ms
# Speed: 0.6ms pre-process, 13.1ms inference, 2.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 8.7ms
# Speed: 0.7ms pre-process, 8.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 12.7ms
# Speed: 0.7ms pre-process, 12.7ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 5 persons, 4 cars, 9.7ms
# Speed: 0.7ms pre-process, 9.7ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 11.1ms
# Speed: 0.9ms pre-process, 11.1ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 2 persons, 4 cars, 8.4ms
# Speed: 0.5ms pre-process, 8.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 8.9ms
# Speed: 0.7ms pre-process, 8.9ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 1 person, 4 cars, 10.8ms
# Speed: 0.6ms pre-process, 10.8ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# Track ID: 1 - Count: 39 - Type: car - Avg Speed: 10.50 pixels/second
# Track ID: 2 - Count: 326 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 3 - Count: 59 - Type: car - Avg Speed: 14.81 pixels/second
# Track ID: 4 - Count: 82 - Type: car - Avg Speed: 9.32 pixels/second
# Track ID: 5 - Count: 232 - Type: truck - Avg Speed: 0.00 pixels/second
# Track ID: 6 - Count: 158 - Type: car - Avg Speed: 10.07 pixels/second
# Track ID: 10 - Count: 2 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 16 - Count: 101 - Type: car - Avg Speed: 17.74 pixels/second
# Track ID: 23 - Count: 17 - Type: bicycle - Avg Speed: 79.14 pixels/second
# Track ID: 25 - Count: 20 - Type: bicycle - Avg Speed: 4.49 pixels/second
# Track ID: 30 - Count: 145 - Type: car - Avg Speed: 8.44 pixels/second
# Track ID: 31 - Count: 3 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 39 - Count: 85 - Type: car - Avg Speed: 6.87 pixels/second
# Track ID: 45 - Count: 4 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 53 - Count: 36 - Type: person - Avg Speed: 44.40 pixels/second
# Track ID: 54 - Count: 71 - Type: car - Avg Speed: 25.34 pixels/second
# Track ID: 55 - Count: 123 - Type: car - Avg Speed: 10.66 pixels/second
# Track ID: 57 - Count: 22 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 58 - Count: 35 - Type: truck - Avg Speed: 0.00 pixels/second
# Track ID: 65 - Count: 92 - Type: car - Avg Speed: 4.66 pixels/second
# Track ID: 66 - Count: 71 - Type: car - Avg Speed: 7.19 pixels/second
# Track ID: 67 - Count: 113 - Type: car - Avg Speed: 22.72 pixels/second
# Track ID: 69 - Count: 129 - Type: truck - Avg Speed: 0.00 pixels/second
# Track ID: 72 - Count: 10 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 76 - Count: 82 - Type: car - Avg Speed: 19.51 pixels/second
# Track ID: 77 - Count: 26 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 79 - Count: 59 - Type: car - Avg Speed: 8.36 pixels/second
# Track ID: 83 - Count: 115 - Type: car - Avg Speed: 8.94 pixels/second
# Track ID: 85 - Count: 13 - Type: car - Avg Speed: 4.15 pixels/second
# Track ID: 93 - Count: 4 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 95 - Count: 48 - Type: car - Avg Speed: 2.76 pixels/second
# Track ID: 100 - Count: 21 - Type: person - Avg Speed: 17.61 pixels/second
# Track ID: 101 - Count: 8 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 103 - Count: 140 - Type: car - Avg Speed: 9.99 pixels/second
# Track ID: 108 - Count: 34 - Type: bus - Avg Speed: 0.00 pixels/second
# Track ID: 116 - Count: 4 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 118 - Count: 93 - Type: car - Avg Speed: 13.96 pixels/second
# Track ID: 130 - Count: 16 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 135 - Count: 78 - Type: car - Avg Speed: 7.77 pixels/second
# Track ID: 138 - Count: 18 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 139 - Count: 40 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 141 - Count: 59 - Type: car - Avg Speed: 14.56 pixels/second
# Track ID: 144 - Count: 15 - Type: person - Avg Speed: 18.31 pixels/second
# Track ID: 145 - Count: 20 - Type: person - Avg Speed: 18.02 pixels/second
# Track ID: 146 - Count: 14 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 151 - Count: 10 - Type: person - Avg Speed: 7.92 pixels/second
# Track ID: 153 - Count: 96 - Type: car - Avg Speed: 11.53 pixels/second
# Track ID: 161 - Count: 25 - Type: person - Avg Speed: 10.57 pixels/second
# Track ID: 176 - Count: 21 - Type: person - Avg Speed: 9.58 pixels/second
# Track ID: 177 - Count: 76 - Type: car - Avg Speed: 25.68 pixels/second
# Track ID: 179 - Count: 6 - Type: person - Avg Speed: 10.92 pixels/second
# Track ID: 180 - Count: 108 - Type: car - Avg Speed: 8.54 pixels/second
# Track ID: 185 - Count: 2 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 188 - Count: 30 - Type: car - Avg Speed: 22.33 pixels/second
# Track ID: 192 - Count: 10 - Type: person - Avg Speed: 44.12 pixels/second
# Track ID: 193 - Count: 10 - Type: person - Avg Speed: 1.70 pixels/second
# Track ID: 194 - Count: 11 - Type: person - Avg Speed: 16.77 pixels/second
# Track ID: 196 - Count: 4 - Type: car - Avg Speed: 5.91 pixels/second
# Track ID: 197 - Count: 27 - Type: car - Avg Speed: 17.11 pixels/second
# Track ID: 202 - Count: 52 - Type: car - Avg Speed: 5.76 pixels/second
# Track ID: 208 - Count: 926 - Type: car - Avg Speed: 4.94 pixels/second
# Track ID: 211 - Count: 56 - Type: car - Avg Speed: 6.16 pixels/second
# Track ID: 215 - Count: 5 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 218 - Count: 2 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 219 - Count: 56 - Type: car - Avg Speed: 3.22 pixels/second
# Track ID: 220 - Count: 8 - Type: car - Avg Speed: 2.35 pixels/second
# Track ID: 221 - Count: 86 - Type: car - Avg Speed: 7.50 pixels/second
# Track ID: 224 - Count: 82 - Type: car - Avg Speed: 6.60 pixels/second
# Track ID: 227 - Count: 49 - Type: car - Avg Speed: 7.47 pixels/second
# Track ID: 231 - Count: 29 - Type: car - Avg Speed: 28.49 pixels/second
# Track ID: 234 - Count: 3 - Type: person - Avg Speed: 28.37 pixels/second
# Track ID: 235 - Count: 95 - Type: car - Avg Speed: 13.74 pixels/second
# Track ID: 236 - Count: 5 - Type: person - Avg Speed: 94.17 pixels/second
# Track ID: 240 - Count: 9 - Type: person - Avg Speed: 22.42 pixels/second
# Track ID: 242 - Count: 12 - Type: person - Avg Speed: 28.68 pixels/second
# Track ID: 244 - Count: 41 - Type: car - Avg Speed: 26.93 pixels/second
# Track ID: 246 - Count: 68 - Type: car - Avg Speed: 11.84 pixels/second
# Track ID: 247 - Count: 5 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 252 - Count: 8 - Type: person - Avg Speed: 3.16 pixels/second
# Track ID: 254 - Count: 28 - Type: car - Avg Speed: 14.34 pixels/second
# Track ID: 256 - Count: 11 - Type: person - Avg Speed: 26.07 pixels/second
# Track ID: 260 - Count: 15 - Type: person - Avg Speed: 14.90 pixels/second
# Track ID: 262 - Count: 23 - Type: person - Avg Speed: 38.05 pixels/second
# Track ID: 263 - Count: 44 - Type: car - Avg Speed: 3.96 pixels/second
# Track ID: 265 - Count: 18 - Type: person - Avg Speed: 33.52 pixels/second
# Track ID: 274 - Count: 69 - Type: car - Avg Speed: 8.80 pixels/second
# Track ID: 280 - Count: 57 - Type: car - Avg Speed: 21.91 pixels/second
# Track ID: 286 - Count: 55 - Type: car - Avg Speed: 17.01 pixels/second
# Track ID: 290 - Count: 10 - Type: person - Avg Speed: 11.89 pixels/second
# Track ID: 292 - Count: 12 - Type: person - Avg Speed: 44.27 pixels/second
# Track ID: 302 - Count: 70 - Type: car - Avg Speed: 44.13 pixels/second
# Track ID: 303 - Count: 24 - Type: car - Avg Speed: 19.14 pixels/second
# Track ID: 306 - Count: 21 - Type: person - Avg Speed: 2.83 pixels/second
# Track ID: 336 - Count: 24 - Type: person - Avg Speed: 11.59 pixels/second
# Track ID: 338 - Count: 16 - Type: person - Avg Speed: 12.61 pixels/second
# Track ID: 344 - Count: 26 - Type: person - Avg Speed: 51.98 pixels/second
# Track ID: 346 - Count: 22 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 348 - Count: 2 - Type: car - Avg Speed: 14.71 pixels/second
# Track ID: 349 - Count: 4 - Type: car - Avg Speed: 33.97 pixels/second
# Track ID: 350 - Count: 18 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 354 - Count: 7 - Type: car - Avg Speed: 56.37 pixels/second
# Track ID: 355 - Count: 35 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 360 - Count: 2 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 361 - Count: 2 - Type: car - Avg Speed: 83.02 pixels/second
# Track ID: 364 - Count: 16 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 371 - Count: 17 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 376 - Count: 2 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 384 - Count: 11 - Type: person - Avg Speed: 61.63 pixels/second
# Track ID: 385 - Count: 7 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 386 - Count: 31 - Type: person - Avg Speed: 21.57 pixels/second
# Track ID: 390 - Count: 20 - Type: person - Avg Speed: 24.47 pixels/second
# Track ID: 394 - Count: 13 - Type: person - Avg Speed: 25.63 pixels/second
# Track ID: 395 - Count: 9 - Type: person - Avg Speed: 18.50 pixels/second
# Track ID: 402 - Count: 9 - Type: traffic light - Avg Speed: 0.00 pixels/second
# Track ID: 403 - Count: 19 - Type: person - Avg Speed: 65.27 pixels/second
# Track ID: 408 - Count: 31 - Type: person - Avg Speed: 92.78 pixels/second
# Track ID: 418 - Count: 15 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 423 - Count: 12 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 428 - Count: 14 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 431 - Count: 23 - Type: person - Avg Speed: 59.86 pixels/second
# Track ID: 433 - Count: 4 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 436 - Count: 12 - Type: person - Avg Speed: 35.31 pixels/second
# Track ID: 438 - Count: 309 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 439 - Count: 38 - Type: person - Avg Speed: 12.63 pixels/second
# Track ID: 443 - Count: 16 - Type: person - Avg Speed: 48.73 pixels/second
# Track ID: 460 - Count: 5 - Type: person - Avg Speed: 6.38 pixels/second
# Track ID: 470 - Count: 14 - Type: person - Avg Speed: 34.94 pixels/second
# Track ID: 481 - Count: 19 - Type: person - Avg Speed: 20.21 pixels/second
# Track ID: 485 - Count: 22 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 495 - Count: 30 - Type: person - Avg Speed: 0.00 pixels/second
# Track ID: 498 - Count: 2 - Type: bicycle - Avg Speed: 10.86 pixels/second
# Track ID: 499 - Count: 56 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 503 - Count: 49 - Type: car - Avg Speed: 52.39 pixels/second
# Track ID: 508 - Count: 13 - Type: potted plant - Avg Speed: 10.91 pixels/second
# Track ID: 516 - Count: 2 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 520 - Count: 56 - Type: car - Avg Speed: 4.27 pixels/second
# Track ID: 524 - Count: 39 - Type: car - Avg Speed: 12.34 pixels/second
# Track ID: 528 - Count: 52 - Type: car - Avg Speed: 14.89 pixels/second
# Track ID: 532 - Count: 235 - Type: car - Avg Speed: 6.72 pixels/second
# Track ID: 533 - Count: 15 - Type: car - Avg Speed: 67.32 pixels/second
# Track ID: 534 - Count: 9 - Type: car - Avg Speed: 20.61 pixels/second
# Track ID: 536 - Count: 21 - Type: car - Avg Speed: 2.12 pixels/second
# Track ID: 539 - Count: 29 - Type: car - Avg Speed: 2.76 pixels/second
# Track ID: 540 - Count: 28 - Type: car - Avg Speed: 17.11 pixels/second
# Track ID: 543 - Count: 39 - Type: car - Avg Speed: 7.11 pixels/second
# Track ID: 546 - Count: 23 - Type: car - Avg Speed: 40.76 pixels/second
# Track ID: 550 - Count: 15 - Type: car - Avg Speed: 10.34 pixels/second
# Track ID: 558 - Count: 107 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 559 - Count: 46 - Type: person - Avg Speed: 25.15 pixels/second
# Track ID: 564 - Count: 85 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 565 - Count: 45 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 567 - Count: 104 - Type: car - Avg Speed: 1.06 pixels/second
# Track ID: 570 - Count: 76 - Type: car - Avg Speed: 3.98 pixels/second
# Track ID: 572 - Count: 36 - Type: car - Avg Speed: 0.00 pixels/second
# Track ID: 573 - Count: 2 - Type: person - Avg Speed: 0.00 pixels/second
# Total number of people: 64
# Total number of parked cars: 12
# Total number of moving cars: 57
